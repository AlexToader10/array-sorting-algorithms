# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexToader10/array-sorting-algorithms/blob/master/fine_tune_whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fine-Tune Whisper For Multilingual ASR with 🤗 Transformers

# %% [markdown]
# In this Colab, we present a step-by-step guide on how to fine-tune Whisper
# for any multilingual ASR dataset using Hugging Face 🤗 Transformers. This is a
# more "hands-on" version of the accompanying [blog post](https://huggingface.co/blog/fine-tune-whisper).
# For a more in-depth explanation of Whisper, the Common Voice dataset and the theory behind fine-tuning, the reader is advised to refer to the blog post.

# %% [markdown]
# ## Introduction

# %% [markdown]
# Whisper is a pre-trained model for automatic speech recognition (ASR)
# published in [September 2022](https://openai.com/blog/whisper/) by the authors
# Alec Radford et al. from OpenAI. Unlike many of its predecessors, such as
# [Wav2Vec 2.0](https://arxiv.org/abs/2006.11477), which are pre-trained
# on un-labelled audio data, Whisper is pre-trained on a vast quantity of
# **labelled** audio-transcription data, 680,000 hours to be precise.
# This is an order of magnitude more data than the un-labelled audio data used
# to train Wav2Vec 2.0 (60,000 hours). What is more, 117,000 hours of this
# pre-training data is multilingual ASR data. This results in checkpoints
# that can be applied to over 96 languages, many of which are considered
# _low-resource_.
#
# When scaled to 680,000 hours of labelled pre-training data, Whisper models
# demonstrate a strong ability to generalise to many datasets and domains.
# The pre-trained checkpoints achieve competitive results to state-of-the-art
# ASR systems, with near 3% word error rate (WER) on the test-clean subset of
# LibriSpeech ASR and a new state-of-the-art on TED-LIUM with 4.7% WER (_c.f._
# Table 8 of the [Whisper paper](https://cdn.openai.com/papers/whisper.pdf)).
# The extensive multilingual ASR knowledge acquired by Whisper during pre-training
# can be leveraged for other low-resource languages; through fine-tuning, the
# pre-trained checkpoints can be adapted for specific datasets and languages
# to further improve upon these results. We'll show just how Whisper can be fine-tuned
# for low-resource languages in this Colab.

# %% [markdown]
# <figure>
# <img src="https://raw.githubusercontent.com/sanchit-gandhi/notebooks/main/whisper_architecture.svg" alt="Trulli" style="width:100%">
# <figcaption align = "center"><b>Figure 1:</b> Whisper model. The architecture
# follows the standard Transformer-based encoder-decoder model. A
# log-Mel spectrogram is input to the encoder. The last encoder
# hidden states are input to the decoder via cross-attention mechanisms. The
# decoder autoregressively predicts text tokens, jointly conditional on the
# encoder hidden states and previously predicted tokens. Figure source:
# <a href="https://openai.com/blog/whisper/">OpenAI Whisper Blog</a>.</figcaption>
# </figure>

# %% [markdown]
# The Whisper checkpoints come in five configurations of varying model sizes.
# The smallest four are trained on either English-only or multilingual data.
# The largest checkpoints are multilingual only. All 11 of the pre-trained checkpoints
# are available on the [Hugging Face Hub](https://huggingface.co/models?search=openai/whisper). The
# checkpoints are summarised in the following table with links to the models on the Hub:
#
# | Size     | Layers | Width | Heads | Parameters | English-only                                         | Multilingual                                        |
# |----------|--------|-------|-------|------------|------------------------------------------------------|-----------------------------------------------------|
# | tiny     | 4      | 384   | 6     | 39 M       | [✓](https://huggingface.co/openai/whisper-tiny.en)   | [✓](https://huggingface.co/openai/whisper-tiny.)    |
# | base     | 6      | 512   | 8     | 74 M       | [✓](https://huggingface.co/openai/whisper-base.en)   | [✓](https://huggingface.co/openai/whisper-base)     |
# | small    | 12     | 768   | 12    | 244 M      | [✓](https://huggingface.co/openai/whisper-small.en)  | [✓](https://huggingface.co/openai/whisper-small)    |
# | medium   | 24     | 1024  | 16    | 769 M      | [✓](https://huggingface.co/openai/whisper-medium.en) | [✓](https://huggingface.co/openai/whisper-medium)   |
# | large    | 32     | 1280  | 20    | 1550 M     | x                                                    | [✓](https://huggingface.co/openai/whisper-large)    |
# | large-v2 | 32     | 1280  | 20    | 1550 M     | x                                                    | [✓](https://huggingface.co/openai/whisper-large-v2) |
# | large-v3 | 32     | 1280  | 20    | 1550 M     | x                                                    | [✓](https://huggingface.co/openai/whisper-large-v3) |
#
#
# For demonstration purposes, we'll fine-tune the multilingual version of the
# [`"small"`](https://huggingface.co/openai/whisper-small) checkpoint with 244M params (~= 1GB).
# As for our data, we'll train and evaluate our system on a low-resource language
# taken from the [Common Voice](https://huggingface.co/datasets/mozilla-foundation/common_voice_11_0)
# dataset. We'll show that with as little as 8 hours of fine-tuning data, we can achieve
# strong performance in this language.

# %% [markdown]
# ------------------------------------------------------------------------
#
# \\({}^1\\) The name Whisper follows from the acronym “WSPSR”, which stands for “Web-scale Supervised Pre-training for Speech Recognition”.

# %% [markdown]
# ## Prepare Environment

# %% [markdown]
# First of all, let's try to secure a decent GPU for our Colab! Unfortunately, it's becoming much harder to get access to a good GPU with the free version of Google Colab. However, with Google Colab Pro one should have no issues in being allocated a V100 or P100 GPU.
#
# To get a GPU, click _Runtime_ -> _Change runtime type_, then change _Hardware accelerator_ from _CPU_ to one of the available GPUs, e.g. _T4_ (or better if you have one available). Next, click `Connect T4` in the top right-hand corner of your screen (or `Connect {V100, A100}` if you selected a different GPU).

# %% [markdown]
# We can verify that we've been assigned a GPU and view its specifications:

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat May  3 15:50:40 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             40W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# We'll employ several popular Python packages to fine-tune the Whisper model.
# We'll use `datasets[audio]` to download and prepare our training data, alongside
# `transformers` and `accelerate` to load and train our Whisper model.
# We'll also require the `soundfile` package to pre-process audio files,
# `evaluate` and `jiwer` to assess the performance of our model, and
# `tensorboard` to log our metrics. Finally, we'll use `gradio` to build a
# flashy demo of our fine-tuned model.

# %%
# !pip install --upgrade --quiet pip
# !pip install fssspec==2025.3.2
# !pip install tensorboard==2.18
# !pip install --upgrade --quiet datasets[audio] transformers accelerate evaluate jiwer tensorboard gradio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 66.4 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement fssspec==2025.3.2 (from versions: none)
# ERROR: No matching distribution found for fssspec==2025.3.2
# Requirement already satisfied: tensorboard==2.18 in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard==2.18) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard==2.18) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard==2.18) (3.8)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard==2.18) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboard==2.18) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard==2.18) (5.29.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard==2.18) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard==2.18) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard==2.18) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard==2.18) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard==2.18) (3.0.2)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 132.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.1/54.1 MB 158.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 101.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 168.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 61.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 215.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 228.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 39.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 168.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 179.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 167.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 100.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 218.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33/33 [evaluate]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# tensorflow 2.18.0 requires tensorboard<2.19,>=2.18, but you have tensorboard 2.19.0 which is incompatible.

# %% [markdown]
# We strongly advise you to upload model checkpoints directly the [Hugging Face Hub](https://huggingface.co/)
# whilst training. The Hub provides:
# - Integrated version control: you can be sure that no model checkpoint is lost during training.
# - Tensorboard logs: track important metrics over the course of training.
# - Model cards: document what a model does and its intended use cases.
# - Community: an easy way to share and collaborate with the community!
#
# Linking the notebook to the Hub is straightforward - it simply requires entering your
# Hub authentication token when prompted. Find your Hub authentication token [here](https://huggingface.co/settings/tokens):

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# Using 🤗 Datasets, downloading and preparing data is extremely simple.
# We can download and prepare the Common Voice splits in just one line of code.
#
# First, ensure you have accepted the terms of use on the Hugging Face Hub: [mozilla-foundation/common_voice_11_0](https://huggingface.co/datasets/mozilla-foundation/common_voice_11_0). Once you have accepted the terms, you will have full access to the dataset and be able to download the data locally.
#
# Since Hindi is very low-resource, we'll combine the `train` and `validation`
# splits to give approximately 8 hours of training data. We'll use the 4 hours
# of `test` data as our held-out test set:

# %%
from datasets import load_dataset, DatasetDict, Dataset
from sklearn.model_selection import train_test_split

common_voice = DatasetDict()

# common_voice["train"] = load_dataset("mozilla-foundation/common_voice_11_0", "hi", split="train+validation")
# common_voice["test"] = load_dataset("mozilla-foundation/common_voice_11_0", "hi", split="test")

# print(common_voice)
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

dataset_path = '/content/drive/MyDrive/fine-tune/final_transcript_data.csv'
df = pd.read_csv(dataset_path)

column_mapping = {
    'audio_path': 'audio',
    'text': 'sentence'
}

df_renamed = df.rename(columns=column_mapping)
df_renamed['sentence'] = df_renamed['sentence'].str[3:]
df_renamed['audio'] = "/content/drive/MyDrive" + df_renamed['audio'].str[70:]
print(df_renamed.head())
print(common_voice)
test_set_size = 0.2  # Use 20% of the data for the test set
random_seed = 42     # Use a fixed seed for reproducibility

# --- Perform the split ---
# This splits the entire DataFrame based on rows
train_df, test_df = train_test_split(
    df_renamed,
    test_size=test_set_size,
    random_state=random_seed,
    shuffle=True  # Shuffle the data before splitting (usually recommended)
)
common_voice["train"] = Dataset.from_pandas(train_df)
common_voice["test"] = Dataset.from_pandas(test_df)
print(common_voice)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                                             sentence  \
# 0   Bună dimineața tuturor, sunt Cristi Coste și ...
# 1  Și chemat. Atâta timp când Micea Lucescu merge...
# 2                                          Tot zero.
# 3  Despre Naționala României, ce știi în mare? Ce...
# 4  Știu că numărul unu este selecționierul. Tata ...
#
#                                                audio
# 0  /content/drive/MyDrive/fine-tune/21_martie_10_...
# 1  /content/drive/MyDrive/fine-tune/21_martie_10_...
# 2  /content/drive/MyDrive/fine-tune/21_martie_10_...
# 3  /content/drive/MyDrive/fine-tune/21_martie_10_...
# 4  /content/drive/MyDrive/fine-tune/21_martie_10_...
# DatasetDict({
#
# })
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'audio', '__index_level_0__'],
#         num_rows: 8545
#     })
#     test: Dataset({
#         features: ['sentence', 'audio', '__index_level_0__'],
#         num_rows: 2137
#     })
# })

# %% [markdown]
# Most ASR datasets only provide input audio samples (`audio`) and the
# corresponding transcribed text (`sentence`). Common Voice contains additional
# metadata information, such as `accent` and `locale`, which we can disregard for ASR.
# Keeping the notebook as general as possible, we only consider the input audio and
# transcribed text for fine-tuning, discarding the additional metadata information:

# %% [markdown]
# ## Prepare Feature Extractor, Tokenizer and Data

# %% [markdown]
# The ASR pipeline can be de-composed into three stages:
#
# 1. A feature extractor which pre-processes the raw audio-inputs
# 2. The model which performs the sequence-to-sequence mapping
# 3. A tokenizer which post-processes the model outputs to text format
#
# In 🤗 Transformers, the Whisper model has an associated feature extractor and tokenizer,
# called [WhisperFeatureExtractor](https://huggingface.co/docs/transformers/main/model_doc/whisper#transformers.WhisperFeatureExtractor)
# and [WhisperTokenizer](https://huggingface.co/docs/transformers/main/model_doc/whisper#transformers.WhisperTokenizer)
# respectively.
#
# We'll go through details for setting-up the feature extractor and tokenizer one-by-one!

# %% [markdown]
# ### Load WhisperFeatureExtractor

# %% [markdown]
# The Whisper feature extractor performs two operations:
# 1. Pads / truncates the audio inputs to 30s: any audio inputs shorter than 30s are padded to 30s with silence (zeros), and those longer that 30s are truncated to 30s
# 2. Converts the audio inputs to _log-Mel spectrogram_ input features, a visual representation of the audio and the form of the input expected by the Whisper model

# %% [markdown]
# <figure>
# <img src="https://raw.githubusercontent.com/sanchit-gandhi/notebooks/main/spectrogram.jpg" alt="Trulli" style="width:100%">
# <figcaption align = "center"><b>Figure 2:</b> Conversion of sampled audio array to log-Mel spectrogram.
# Left: sampled 1-dimensional audio signal. Right: corresponding log-Mel spectrogram. Figure source:
# <a href="https://ai.googleblog.com/2019/04/specaugment-new-data-augmentation.html">Google SpecAugment Blog</a>.
# </figcaption>

# %% [markdown]
# We'll load the feature extractor from the pre-trained checkpoint with the default values:

# %%
from transformers import WhisperFeatureExtractor

feature_extractor = WhisperFeatureExtractor.from_pretrained("openai/whisper-large-v3")
# Out:
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]

# %% [markdown]
# ### Load WhisperTokenizer

# %% [markdown]
# The Whisper model outputs a sequence of _token ids_. The tokenizer maps each of these token ids to their corresponding text string. For Hindi, we can load the pre-trained tokenizer and use it for fine-tuning without any further modifications. We simply have to
# specify the target language and the task. These arguments inform the
# tokenizer to prefix the language and task tokens to the start of encoded
# label sequences:

# %%
from transformers import WhisperTokenizer

tokenizer = WhisperTokenizer.from_pretrained("openai/whisper-large-v3", language="Romanian", task="transcribe")
# Out:
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.07k [00:00<?, ?B/s]

# %% [markdown]
# ### Combine To Create A WhisperProcessor

# %% [markdown]
# To simplify using the feature extractor and tokenizer, we can _wrap_
# both into a single `WhisperProcessor` class. This processor object
# inherits from the `WhisperFeatureExtractor` and `WhisperProcessor`,
# and can be used on the audio inputs and model predictions as required.
# In doing so, we only need to keep track of two objects during training:
# the `processor` and the `model`:

# %%
from transformers import WhisperProcessor

processor = WhisperProcessor.from_pretrained("openai/whisper-large-v3", language="Romanian", task="transcribe")

# %% [markdown]
# ### Prepare Data

# %% [markdown]
# Let's print the first example of the Common Voice dataset to see
# what form the data is in:

# %%
print(common_voice["train"][0])

# %%
# !pip install librosa

# %%
import librosa
import numpy as np
import soundfile as sf # Often used by librosa under the hood or as alternative

def load_wav_to_array(file_path, target_sr=None):
    """
    Loads a WAV file into a NumPy array and returns the array and sampling rate.

    Args:
        file_path (str): Path to the .wav file.
        target_sr (int, optional): Target sampling rate to resample to.
                                   If None, loads at the native sampling rate.
                                   Defaults to None.

    Returns:
        tuple: A tuple containing:
            - np.ndarray: The audio waveform as a NumPy array (floating-point).
            - int: The sampling rate of the audio array.
        Returns (None, None) if loading fails.
    """
    try:
        # Load the audio file. librosa automatically converts to float
        # and optionally resamples. It defaults to mono.
        audio_array, sampling_rate = librosa.load(file_path, sr=target_sr, mono=True)
        print(f"Loaded '{file_path}'")
        print(f"Native Sampling Rate: {librosa.get_samplerate(file_path)}") # Get original rate before potential resampling
        print(f"Array Sampling Rate (after potential resampling): {sampling_rate}")
        print(f"Array Shape: {audio_array.shape}")
        print(f"Array dtype: {audio_array.dtype}") # Should be float32 usually
        print(f"Array min/max: {np.min(audio_array):.4f} / {np.max(audio_array):.4f}") # Check normalization range

        return {'path' : file_path, 'array': audio_array, 'sampling_rate': sampling_rate}
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None, None

# # --- Example Usage ---
# # Replace with the actual path to YOUR .wav file
# your_wav_file = 'path/to/your/audio.wav' # <--- CHANGE THIS

# # Option 1: Load at native sampling rate
# print("\n--- Loading at native SR ---")
# waveform_native, sr_native = load_wav_to_array(your_wav_file, target_sr=None)

# if waveform_native is not None:
#     # Now 'waveform_native' is the NumPy array you want, similar to the 'array' field
#     # 'sr_native' is the corresponding sampling rate
#     print("First 10 samples (native SR):", waveform_native[:10])

# # Option 2: Load and resample to a specific rate (e.g., 16000 Hz like your example)
# print("\n--- Loading and resampling to 16000 Hz ---")
# target_sampling_rate = 16000
# waveform_resampled, sr_resampled = load_wav_to_array(your_wav_file, target_sr=target_sampling_rate)

# if waveform_resampled is not None:
#     # 'waveform_resampled' is the NumPy array resampled to 16kHz
#     # 'sr_resampled' should be 16000
#     print(f"Sampling rate is now: {sr_resampled}")
#     print("First 10 samples (resampled):", waveform_resampled[:10])

#     # You can create the dictionary structure if needed:
#     audio_dict = {
#         'path': your_wav_file,
#         'array': waveform_resampled,
#         'sampling_rate': sr_resampled
#     }
#     # print("\nDictionary structure:")
#     # print(audio_dict) # This will print the full array, potentially very long

df_renamed['audio'] = df_renamed['audio'].apply(lambda x: load_wav_to_array(x))
# Out:
# Datele de ieșire de afișat au fost trunchiate la ultimele 5000 linii.
# Array dtype: float32
# Array min/max: -0.6787 / 0.6694
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_485/transcript_485.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6363 / 0.6476
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_486/transcript_486.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (3648000,)
# Array dtype: float32
# Array min/max: -0.6730 / 0.7276
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_487/transcript_487.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6586 / 0.6443
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_488/transcript_488.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (672000,)
# Array dtype: float32
# Array min/max: -0.6850 / 0.6992
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_489/transcript_489.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1104000,)
# Array dtype: float32
# Array min/max: -0.6613 / 0.6682
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_49/transcript_49.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6205 / 0.5903
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_490/transcript_490.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6562 / 0.6698
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_491/transcript_491.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6480 / 0.6707
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_492/transcript_492.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6193 / 0.6545
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_493/transcript_493.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (912000,)
# Array dtype: float32
# Array min/max: -0.6463 / 0.6535
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_494/transcript_494.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6584 / 0.6568
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_495/transcript_495.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6662 / 0.6478
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_496/transcript_496.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.7012 / 0.6830
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_497/transcript_497.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6561 / 0.6527
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_498/transcript_498.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6642 / 0.7025
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_499/transcript_499.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6382 / 0.6494
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_5/transcript_5.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (288000,)
# Array dtype: float32
# Array min/max: -0.6169 / 0.6143
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_50/transcript_50.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (2208000,)
# Array dtype: float32
# Array min/max: -0.6254 / 0.6660
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_500/transcript_500.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (816000,)
# Array dtype: float32
# Array min/max: -0.6644 / 0.6871
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_501/transcript_501.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6640 / 0.6480
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_502/transcript_502.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (672000,)
# Array dtype: float32
# Array min/max: -0.6506 / 0.6794
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_503/transcript_503.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.5224 / 0.4284
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_504/transcript_504.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.5224 / 0.4284
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_505/transcript_505.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.6449 / 0.6473
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_506/transcript_506.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (288000,)
# Array dtype: float32
# Array min/max: -0.6505 / 0.6482
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_507/transcript_507.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (384000,)
# Array dtype: float32
# Array min/max: -0.6655 / 0.6492
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_508/transcript_508.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.4491 / 0.3374
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_509/transcript_509.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.6472 / 0.6558
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_51/transcript_51.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.5716 / 0.5186
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_510/transcript_510.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6487 / 0.6696
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_511/transcript_511.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6518 / 0.6330
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_512/transcript_512.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6366 / 0.5951
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_513/transcript_513.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6348 / 0.6683
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_514/transcript_514.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.5898 / 0.6069
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_515/transcript_515.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1344000,)
# Array dtype: float32
# Array min/max: -0.7099 / 0.6875
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_516/transcript_516.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (2640000,)
# Array dtype: float32
# Array min/max: -0.6935 / 0.7002
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_517/transcript_517.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (528000,)
# Array dtype: float32
# Array min/max: -0.6575 / 0.6530
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_518/transcript_518.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6322 / 0.6131
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_519/transcript_519.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6010 / 0.5218
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_52/transcript_52.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (672000,)
# Array dtype: float32
# Array min/max: -0.6281 / 0.6578
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_520/transcript_520.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1536000,)
# Array dtype: float32
# Array min/max: -0.6512 / 0.6738
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_521/transcript_521.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6022 / 0.6171
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_522/transcript_522.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (384000,)
# Array dtype: float32
# Array min/max: -0.6431 / 0.6341
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_523/transcript_523.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.5556 / 0.5807
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_524/transcript_524.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.6445 / 0.6584
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_525/transcript_525.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6075 / 0.5638
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_526/transcript_526.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (480000,)
# Array dtype: float32
# Array min/max: -0.6385 / 0.6531
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_527/transcript_527.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6108 / 0.6476
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_528/transcript_528.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.6539 / 0.6429
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_529/transcript_529.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (816000,)
# Array dtype: float32
# Array min/max: -0.6646 / 0.6678
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_53/transcript_53.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6103 / 0.6660
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_530/transcript_530.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6659 / 0.6316
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_531/transcript_531.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6545 / 0.6555
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_532/transcript_532.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6489 / 0.6160
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_533/transcript_533.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6636 / 0.6438
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_534/transcript_534.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6239 / 0.6277
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_535/transcript_535.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6227 / 0.6516
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_536/transcript_536.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6756 / 0.6524
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_537/transcript_537.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.6383 / 0.6257
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_538/transcript_538.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (624000,)
# Array dtype: float32
# Array min/max: -0.6703 / 0.6651
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_539/transcript_539.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1632000,)
# Array dtype: float32
# Array min/max: -0.6746 / 0.6654
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_54/transcript_54.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6450 / 0.6510
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_540/transcript_540.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6266 / 0.6172
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_541/transcript_541.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6579 / 0.6407
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_542/transcript_542.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6324 / 0.6384
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_543/transcript_543.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (384000,)
# Array dtype: float32
# Array min/max: -0.6561 / 0.6476
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_544/transcript_544.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6248 / 0.6331
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_545/transcript_545.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6422 / 0.6810
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_546/transcript_546.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6394 / 0.6351
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_547/transcript_547.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.6559 / 0.6532
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_548/transcript_548.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1296000,)
# Array dtype: float32
# Array min/max: -0.6684 / 0.6587
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_549/transcript_549.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6646 / 0.6590
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_55/transcript_55.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1296000,)
# Array dtype: float32
# Array min/max: -0.6568 / 0.6732
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_550/transcript_550.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6365 / 0.6183
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_551/transcript_551.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6365 / 0.6247
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_552/transcript_552.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6152 / 0.6171
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_553/transcript_553.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.5835 / 0.5216
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_554/transcript_554.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (432000,)
# Array dtype: float32
# Array min/max: -0.6522 / 0.6583
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_555/transcript_555.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (288000,)
# Array dtype: float32
# Array min/max: -0.6431 / 0.6839
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_556/transcript_556.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6679 / 0.6365
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_557/transcript_557.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6455 / 0.6327
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_558/transcript_558.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6261 / 0.6446
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_559/transcript_559.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6504 / 0.6613
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_56/transcript_56.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6245 / 0.6142
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_560/transcript_560.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (432000,)
# Array dtype: float32
# Array min/max: -0.6452 / 0.6518
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_561/transcript_561.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (576000,)
# Array dtype: float32
# Array min/max: -0.6540 / 0.6586
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_562/transcript_562.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6415 / 0.6545
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_563/transcript_563.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1056000,)
# Array dtype: float32
# Array min/max: -0.6709 / 0.6805
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_564/transcript_564.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6378 / 0.6569
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_565/transcript_565.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6163 / 0.6582
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_566/transcript_566.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (576000,)
# Array dtype: float32
# Array min/max: -0.6608 / 0.6852
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_567/transcript_567.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1200000,)
# Array dtype: float32
# Array min/max: -0.6711 / 0.6712
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_568/transcript_568.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.6608 / 0.6523
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_569/transcript_569.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (672000,)
# Array dtype: float32
# Array min/max: -0.6576 / 0.6697
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_57/transcript_57.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6527 / 0.6467
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_570/transcript_570.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6258 / 0.6337
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_571/transcript_571.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6562 / 0.6254
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_572/transcript_572.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.5840 / 0.5575
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_573/transcript_573.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (672000,)
# Array dtype: float32
# Array min/max: -0.6444 / 0.6626
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_574/transcript_574.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6426 / 0.6704
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_575/transcript_575.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (528000,)
# Array dtype: float32
# Array min/max: -0.6720 / 0.6629
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_576/transcript_576.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1536000,)
# Array dtype: float32
# Array min/max: -0.6665 / 0.6653
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_577/transcript_577.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6509 / 0.6429
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_578/transcript_578.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6307 / 0.6472
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_579/transcript_579.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.4870 / 0.5177
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_58/transcript_58.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.5685 / 0.5435
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_580/transcript_580.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (672000,)
# Array dtype: float32
# Array min/max: -0.6673 / 0.6727
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_581/transcript_581.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (288000,)
# Array dtype: float32
# Array min/max: -0.7047 / 0.6750
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_582/transcript_582.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1392000,)
# Array dtype: float32
# Array min/max: -0.6517 / 0.6548
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_583/transcript_583.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6383 / 0.6384
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_584/transcript_584.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6077 / 0.6526
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_585/transcript_585.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (288000,)
# Array dtype: float32
# Array min/max: -0.6961 / 0.6510
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_586/transcript_586.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6531 / 0.6620
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_587/transcript_587.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6470 / 0.6705
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_588/transcript_588.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6350 / 0.6478
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_589/transcript_589.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6505 / 0.6551
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_59/transcript_59.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (3216000,)
# Array dtype: float32
# Array min/max: -0.6428 / 0.6570
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_590/transcript_590.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6730 / 0.6672
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_591/transcript_591.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.6745 / 0.6584
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_592/transcript_592.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.6552 / 0.7065
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_593/transcript_593.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6673 / 0.6721
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_594/transcript_594.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6418 / 0.6500
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_595/transcript_595.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6417 / 0.6096
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_596/transcript_596.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (288000,)
# Array dtype: float32
# Array min/max: -0.6573 / 0.6541
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_597/transcript_597.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6029 / 0.6153
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_598/transcript_598.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6480 / 0.7308
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_599/transcript_599.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (576000,)
# Array dtype: float32
# Array min/max: -0.6528 / 0.6765
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_6/transcript_6.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.0233 / 0.0278
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_60/transcript_60.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.5403 / 0.5358
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_600/transcript_600.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (960000,)
# Array dtype: float32
# Array min/max: -0.6539 / 0.6711
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_601/transcript_601.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6395 / 0.6305
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_602/transcript_602.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (288000,)
# Array dtype: float32
# Array min/max: -0.6507 / 0.6498
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_603/transcript_603.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (384000,)
# Array dtype: float32
# Array min/max: -0.6679 / 0.6710
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_604/transcript_604.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6380 / 0.6505
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_605/transcript_605.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6568 / 0.6481
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_606/transcript_606.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.5939 / 0.6167
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_607/transcript_607.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6541 / 0.6620
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_608/transcript_608.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.5970 / 0.6407
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_609/transcript_609.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (480000,)
# Array dtype: float32
# Array min/max: -0.6396 / 0.6403
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_61/transcript_61.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (288000,)
# Array dtype: float32
# Array min/max: -0.6403 / 0.6464
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_610/transcript_610.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6235 / 0.6426
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_611/transcript_611.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (672000,)
# Array dtype: float32
# Array min/max: -0.6738 / 0.6535
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_612/transcript_612.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6580 / 0.6472
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_613/transcript_613.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6417 / 0.6491
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_614/transcript_614.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6347 / 0.6718
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_615/transcript_615.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (432000,)
# Array dtype: float32
# Array min/max: -0.6602 / 0.6591
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_616/transcript_616.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6414 / 0.6471
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_617/transcript_617.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6565 / 0.6606
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_618/transcript_618.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6667 / 0.6776
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_619/transcript_619.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.5650 / 0.6510
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_62/transcript_62.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1344000,)
# Array dtype: float32
# Array min/max: -0.6620 / 0.6570
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_620/transcript_620.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6297 / 0.6003
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_621/transcript_621.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1296000,)
# Array dtype: float32
# Array min/max: -0.6543 / 0.6504
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_622/transcript_622.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (288000,)
# Array dtype: float32
# Array min/max: -0.6479 / 0.6582
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_623/transcript_623.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1584000,)
# Array dtype: float32
# Array min/max: -0.6588 / 0.6530
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_624/transcript_624.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (8592000,)
# Array dtype: float32
# Array min/max: -0.7297 / 0.7255
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_63/transcript_63.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (960000,)
# Array dtype: float32
# Array min/max: -0.6230 / 0.5973
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_64/transcript_64.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (4320000,)
# Array dtype: float32
# Array min/max: -0.6330 / 0.6467
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_65/transcript_65.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.5711 / 0.6172
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_66/transcript_66.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (3696000,)
# Array dtype: float32
# Array min/max: -0.6411 / 0.6519
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_67/transcript_67.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6241 / 0.6519
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_68/transcript_68.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6149 / 0.6118
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_69/transcript_69.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1248000,)
# Array dtype: float32
# Array min/max: -0.6582 / 0.6641
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_7/transcript_7.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6306 / 0.6382
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_70/transcript_70.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.4939 / 0.5960
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_71/transcript_71.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1152000,)
# Array dtype: float32
# Array min/max: -0.6189 / 0.6335
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_72/transcript_72.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (5808000,)
# Array dtype: float32
# Array min/max: -0.6686 / 0.7592
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_73/transcript_73.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (960000,)
# Array dtype: float32
# Array min/max: -0.6774 / 0.6597
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_74/transcript_74.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6432 / 0.6523
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_75/transcript_75.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6407 / 0.6351
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_76/transcript_76.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6639 / 0.6896
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_77/transcript_77.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.4696 / 0.6155
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_78/transcript_78.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6023 / 0.6155
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_79/transcript_79.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1008000,)
# Array dtype: float32
# Array min/max: -0.6747 / 0.6665
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_8/transcript_8.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6148 / 0.6157
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_80/transcript_80.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6357 / 0.6537
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_81/transcript_81.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (528000,)
# Array dtype: float32
# Array min/max: -0.6728 / 0.6596
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_82/transcript_82.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6118 / 0.6593
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_83/transcript_83.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1680000,)
# Array dtype: float32
# Array min/max: -0.6941 / 0.6609
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_84/transcript_84.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.5623 / 0.6422
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_85/transcript_85.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (384000,)
# Array dtype: float32
# Array min/max: -0.6503 / 0.6662
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_86/transcript_86.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6655 / 0.6480
# Loaded '/content/drive/MyDrive/fine-tune/22_martie_10_30/transcript/transcript_87/transcript_87.wav'
# Native Sampling Rate: 48000
# ...
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6489 / 0.6425
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_633/transcript_633.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6321 / 0.6422
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_634/transcript_634.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1536000,)
# Array dtype: float32
# Array min/max: -0.6639 / 0.6475
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_635/transcript_635.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6163 / 0.5610
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_636/transcript_636.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1104000,)
# Array dtype: float32
# Array min/max: -0.6467 / 0.6343
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_637/transcript_637.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.4198 / 0.4182
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_638/transcript_638.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1248000,)
# Array dtype: float32
# Array min/max: -0.6121 / 0.6540
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_639/transcript_639.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (576000,)
# Array dtype: float32
# Array min/max: -0.6291 / 0.6577
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_64/transcript_64.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.5884 / 0.5568
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_640/transcript_640.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6375 / 0.6365
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_641/transcript_641.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.6563 / 0.6653
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_642/transcript_642.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (192000,)
# Array dtype: float32
# Array min/max: -0.6535 / 0.6486
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_643/transcript_643.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6184 / 0.6245
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_644/transcript_644.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (288000,)
# Array dtype: float32
# Array min/max: -0.6429 / 0.6490
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_645/transcript_645.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (384000,)
# Array dtype: float32
# Array min/max: -0.6640 / 0.6438
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_646/transcript_646.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (384000,)
# Array dtype: float32
# Array min/max: -0.6469 / 0.6336
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_647/transcript_647.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (576000,)
# Array dtype: float32
# Array min/max: -0.6373 / 0.6485
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_648/transcript_648.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6198 / 0.6390
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_649/transcript_649.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (576000,)
# Array dtype: float32
# Array min/max: -0.6452 / 0.6491
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_65/transcript_65.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6506 / 0.6319
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_650/transcript_650.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6751 / 0.6740
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_651/transcript_651.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6104 / 0.6153
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_652/transcript_652.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6446 / 0.6389
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_653/transcript_653.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (432000,)
# Array dtype: float32
# Array min/max: -0.6612 / 0.6574
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_654/transcript_654.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1296000,)
# Array dtype: float32
# Array min/max: -0.6664 / 0.6603
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_655/transcript_655.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6378 / 0.5936
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_656/transcript_656.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (672000,)
# Array dtype: float32
# Array min/max: -0.6449 / 0.6525
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_657/transcript_657.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.6171 / 0.6245
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_658/transcript_658.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6419 / 0.6316
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_659/transcript_659.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.6308 / 0.6489
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_66/transcript_66.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (240000,)
# Array dtype: float32
# Array min/max: -0.6392 / 0.6295
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_660/transcript_660.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6447 / 0.6312
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_661/transcript_661.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6186 / 0.6301
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_662/transcript_662.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (1632000,)
# Array dtype: float32
# Array min/max: -0.6551 / 0.6887
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_663/transcript_663.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.6423 / 0.6538
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_664/transcript_664.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (576000,)
# Array dtype: float32
# Array min/max: -0.6459 / 0.6546
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_665/transcript_665.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (480000,)
# Array dtype: float32
# Array min/max: -0.6511 / 0.6532
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_666/transcript_666.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.6660 / 0.6354
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_667/transcript_667.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.2718 / 0.2346
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_668/transcript_668.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (288000,)
# Array dtype: float32
# Array min/max: -0.4435 / 0.4123
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_669/transcript_669.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (96000,)
# Array dtype: float32
# Array min/max: -0.3058 / 0.2973
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_67/transcript_67.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (336000,)
# Array dtype: float32
# Array min/max: -0.6455 / 0.6489
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_670/transcript_670.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (624000,)
# Array dtype: float32
# Array min/max: -0.6439 / 0.6424
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_671/transcript_671.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (144000,)
# Array dtype: float32
# Array min/max: -0.5893 / 0.6200
# Loaded '/content/drive/MyDrive/fine-tune/25_martie_10_30/transcript/transcript_672/transcript_672.wav'
# Native Sampling Rate: 48000
# Array Sampling Rate (after potential resampling): 48000
# Array Shape: (48000,)
# Array dtype: float32
# Array min/max: -0.5593 / 0.6328
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-73869eaa2885> in <cell line: 0>()
#      68 #     # print(audio_dict) # This will print the full array, potentially very long
#      69
# ---> 70 df_renamed['audio'] = df_renamed['audio'].apply(lambda x: load_wav_to_array(x))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-9-73869eaa2885> in <lambda>(x)
#      68 #     # print(audio_dict) # This will print the full array, potentially very long
#      69
# ---> 70 df_renamed['audio'] = df_renamed['audio'].apply(lambda x: load_wav_to_array(x))
#
# <ipython-input-9-73869eaa2885> in load_wav_to_array(file_path, target_sr)
#      22         # Load the audio file. librosa automatically converts to float
#      23         # and optionally resamples. It defaults to mono.
# ---> 24         audio_array, sampling_rate = librosa.load(file_path, sr=target_sr, mono=True)
#      25         print(f"Loaded '{file_path}'")
#      26         print(f"Native Sampling Rate: {librosa.get_samplerate(file_path)}") # Get original rate before potential resampling
#
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     174         # Otherwise try soundfile first, and then fall back if necessary
#     175         try:
# --> 176             y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     177
#     178         except sf.SoundFileRuntimeError as exc:
#
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py in __soundfile_load(path, offset, duration, dtype)
#     207     else:
#     208         # Otherwise, create the soundfile object
# --> 209         context = sf.SoundFile(path)
#     210
#     211     with context as sf_desc:
#
# /usr/local/lib/python3.11/dist-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd, compression_level, bitrate_mode)
#     688         self._info = _create_info_struct(file, mode, samplerate, channels,
#     689                                          format, subtype, endian)
# --> 690         self._file = self._open(file, mode_int, closefd)
#     691         if set(mode).issuperset('r+') and self.seekable():
#     692             # Move write position to 0 (like in Python file objects)
#
# /usr/local/lib/python3.11/dist-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1252                 else:
#    1253                     file = file.encode(_sys.getfilesystemencoding())
# -> 1254             file_ptr = openfunction(file, mode_int, self._info)
#    1255         elif isinstance(file, int):
#    1256             file_ptr = _snd.sf_open_fd(file, mode_int, self._info, closefd)
#
# KeyboardInterrupt:

# %% [markdown]
# Since
# our input audio is sampled at 48kHz, we need to _downsample_ it to
# 16kHz prior to passing it to the Whisper feature extractor, 16kHz being the sampling rate expected by the Whisper model.
#
# We'll set the audio inputs to the correct sampling rate using dataset's
# [`cast_column`](https://huggingface.co/docs/datasets/package_reference/main_classes.html?highlight=cast_column#datasets.DatasetDict.cast_column)
# method. This operation does not change the audio in-place,
# but rather signals to `datasets` to resample audio samples _on the fly_ the
# first time that they are loaded:

# %%
from datasets import Audio

common_voice = common_voice.cast_column("audio", Audio(sampling_rate=16000))

# %% [markdown]
# Re-loading the first audio sample in the Common Voice dataset will resample
# it to the desired sampling rate:

# %%
print(common_voice["train"][0])
# Out:
# {'sentence': 'Greu. E foarte greu.', 'audio': {'path': '/content/drive/MyDrive/fine-tune/29_aprilie_10_30/transcript/transcript_340/transcript_340.wav', 'array': array([-0.00318118, -0.0051054 , -0.00253131, ...,  0.02895716,
#         0.02173444,  0.01539826]), 'sampling_rate': 16000}, '__index_level_0__': 10004}

# %% [markdown]
# Now we can write a function to prepare our data ready for the model:
# 1. We load and resample the audio data by calling `batch["audio"]`. As explained above, 🤗 Datasets performs any necessary resampling operations on the fly.
# 2. We use the feature extractor to compute the log-Mel spectrogram input features from our 1-dimensional audio array.
# 3. We encode the transcriptions to label ids through the use of the tokenizer.

# %%
def prepare_dataset(batch):
    # load and resample audio data from 48 to 16kHz
    audio = batch["audio"]

    # compute log-Mel input features from input audio array
    batch["input_features"] = feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]

    # encode target text to label ids
    batch["labels"] = tokenizer(batch["sentence"]).input_ids
    return batch

# %% [markdown]
# We can apply the data preparation function to all of our training examples using dataset's `.map` method. The argument `num_proc` specifies how many CPU cores to use. Setting `num_proc` > 1 will enable multiprocessing. If the `.map` method hangs with multiprocessing, set `num_proc=1` and process the dataset sequentially.

# %%
common_voice = common_voice.map(prepare_dataset, remove_columns=common_voice.column_names["train"], num_proc=2)
# Out:
# Map (num_proc=2):   0%|          | 0/8545 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/2137 [00:00<?, ? examples/s]

# %% [markdown]
# ## Training and Evaluation

# %% [markdown]
# Now that we've prepared our data, we're ready to dive into the training pipeline.
# The [🤗 Trainer](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer)
# will do much of the heavy lifting for us. All we have to do is:
#
# - Load a pre-trained checkpoint: we need to load a pre-trained checkpoint and configure it correctly for training.
#
# - Define a data collator: the data collator takes our pre-processed data and prepares PyTorch tensors ready for the model.
#
# - Evaluation metrics: during evaluation, we want to evaluate the model using the [word error rate (WER)](https://huggingface.co/metrics/wer) metric. We need to define a `compute_metrics` function that handles this computation.
#
# - Define the training configuration: this will be used by the 🤗 Trainer to define the training schedule.
#
# Once we've fine-tuned the model, we will evaluate it on the test data to verify that we have correctly trained it
# to transcribe speech in Hindi.

# %% [markdown]
# ### Load a Pre-Trained Checkpoint

# %% [markdown]
# We'll start our fine-tuning run from the pre-trained Whisper `small` checkpoint,
# the weights for which we need to load from the Hugging Face Hub. Again, this
# is trivial through use of 🤗 Transformers!

# %%
from transformers import WhisperForConditionalGeneration

model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-large-v3")
# Out:
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.90k [00:00<?, ?B/s]

# %% [markdown]
# We can disable the automatic language detection task performed during inference, and force the model to generate in Hindi. To do so, we set the [langauge](https://huggingface.co/docs/transformers/en/model_doc/whisper#transformers.WhisperForConditionalGeneration.generate.language)
# and [task](https://huggingface.co/docs/transformers/en/model_doc/whisper#transformers.WhisperForConditionalGeneration.generate.task)
# arguments to the generation config. We'll also set any [`forced_decoder_ids`](https://huggingface.co/docs/transformers/main_classes/text_generation#transformers.generation_utils.GenerationMixin.generate.forced_decoder_ids)
# to None, since this was the legacy way of setting the language and
# task arguments:

# %%
model.generation_config.language = "romanian"
model.generation_config.task = "transcribe"

model.generation_config.forced_decoder_ids = None

# %% [markdown]
# ### Define a Data Collator

# %% [markdown]
# The data collator for a sequence-to-sequence speech model is unique in the sense that it
# treats the `input_features` and `labels` independently: the  `input_features` must be
# handled by the feature extractor and the `labels` by the tokenizer.
#
# The `input_features` are already padded to 30s and converted to a log-Mel spectrogram
# of fixed dimension by action of the feature extractor, so all we have to do is convert the `input_features`
# to batched PyTorch tensors. We do this using the feature extractor's `.pad` method with `return_tensors=pt`.
#
# The `labels` on the other hand are un-padded. We first pad the sequences
# to the maximum length in the batch using the tokenizer's `.pad` method. The padding tokens
# are then replaced by `-100` so that these tokens are **not** taken into account when
# computing the loss. We then cut the BOS token from the start of the label sequence as we
# append it later during training.
#
# We can leverage the `WhisperProcessor` we defined earlier to perform both the
# feature extractor and the tokenizer operations:

# %%
import torch

from dataclasses import dataclass
from typing import Any, Dict, List, Union

@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any
    decoder_start_token_id: int

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        # pad the labels to max length
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.decoder_start_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %% [markdown]
# Let's initialise the data collator we've just defined:

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(
    processor=processor,
    decoder_start_token_id=model.config.decoder_start_token_id,
)

# %% [markdown]
# ### Evaluation Metrics

# %% [markdown]
# We'll use the word error rate (WER) metric, the 'de-facto' metric for assessing
# ASR systems. For more information, refer to the WER [docs](https://huggingface.co/metrics/wer). We'll load the WER metric from 🤗 Evaluate:

# %%
import evaluate

metric = evaluate.load("wer")
# Out:
# Downloading builder script:   0%|          | 0.00/4.49k [00:00<?, ?B/s]

# %% [markdown]
# We then simply have to define a function that takes our model
# predictions and returns the WER metric. This function, called
# `compute_metrics`, first replaces `-100` with the `pad_token_id`
# in the `label_ids` (undoing the step we applied in the
# data collator to ignore padded tokens correctly in the loss).
# It then decodes the predicted and label ids to strings. Finally,
# it computes the WER between the predictions and reference labels:

# %%
def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # replace -100 with the pad_token_id
    label_ids[label_ids == -100] = tokenizer.pad_token_id

    # we do not want to group tokens when computing the metrics
    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)

    wer = 100 * metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %% [markdown]
# ### Define the Training Configuration

# %% [markdown]
# In the final step, we define all the parameters related to training. For more detail on the training arguments, refer to the Seq2SeqTrainingArguments [docs](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.Seq2SeqTrainingArguments).

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="./whisper-large-v3-ro",  # change to a repo name of your choice
    per_device_train_batch_size=16,
    gradient_accumulation_steps=1,  # increase by 2x for every 2x decrease in batch size
    learning_rate=1e-5,
    warmup_steps=500,
    max_steps=4000,
    gradient_checkpointing=True,
    fp16=True,
    eval_strategy="steps",
    per_device_eval_batch_size=8,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=1000,
    eval_steps=1000,
    logging_steps=25,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=True,
)

# %% [markdown]
# **Note**: if one does not want to upload the model checkpoints to the Hub,
# set `push_to_hub=False`.

# %% [markdown]
# We can forward the training arguments to the 🤗 Trainer along with our model,
# dataset, data collator and `compute_metrics` function:

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=common_voice["train"],
    eval_dataset=common_voice["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor.feature_extractor,
)
# Out:
# <ipython-input-45-69786f5d74d5>:3: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(

# %% [markdown]
# We'll save the processor object once before starting training. Since the processor is not trainable, it won't change over the course of training:

# %%
processor.save_pretrained(training_args.output_dir)
# Out:
# []

# %%
max_label_length = 448
def filter_labels_by_length(batch):
    """
    Checks if the length of each 'labels' list in the batch is within the limit.

    Assumes 'labels' contains token IDs. We subtract 2 from max_label_length
    to reserve space for potential BOS/EOS tokens that might be handled by
    the model or data collator separately. If your 'labels' already include
    all necessary special tokens, you might adjust this check to:
    `len(label) <= max_label_length`
    """
    label_lengths = [len(label) for label in batch['labels']]

    # Determine which examples to keep based on label length.
    # Reserve 2 tokens for BOS/EOS unless they are already in 'labels'.
    keep_indices = [length <= (max_label_length - 2) for length in label_lengths]
    return keep_indices

filtered_common_voice = common_voice.filter(filter_labels_by_length, batched=True)
print(filtered_common_voice)
print(common_voice)
common_voice = filtered_common_voice
# Out:
# Filter:   0%|          | 0/8468 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/2112 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_features', 'labels'],
#         num_rows: 8468
#     })
#     test: Dataset({
#         features: ['input_features', 'labels'],
#         num_rows: 2112
#     })
# })
# DatasetDict({
#     train: Dataset({
#         features: ['input_features', 'labels'],
#         num_rows: 8468
#     })
#     test: Dataset({
#         features: ['input_features', 'labels'],
#         num_rows: 2112
#     })
# })

# %% [markdown]
# ### Training

# %% [markdown]
# Training will take approximately 5-10 hours depending on your GPU or the one
# allocated to this Google Colab. If using this Google Colab directly to
# fine-tune a Whisper model, you should make sure that training isn't
# interrupted due to inactivity. A simple workaround to prevent this is
# to paste the following code into the console of this tab (_right mouse click_
# -> _inspect_ -> _Console tab_ -> _insert code_).

# %% [markdown]
# ```javascript
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
# setInterval(ConnectButton, 60000);
# ```

# %% [markdown]
# The peak GPU memory for the given training configuration is approximately 15.8GB.
# Depending on the GPU allocated to the Google Colab, it is possible that you will encounter a CUDA `"out-of-memory"` error when you launch training.
# In this case, you can reduce the `per_device_train_batch_size` incrementally by factors of 2
# and employ [`gradient_accumulation_steps`](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.Seq2SeqTrainingArguments.gradient_accumulation_steps)
# to compensate.
#
# To launch training, simply execute:

# %%
trainer.train()
# Out:
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
#     <div>
#
#       <progress value='1001' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1001/4000 1:17:29 < 3:52:38, 0.21 it/s, Epoch 1.89/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-3435b262f1ae> in <cell line: 0>()
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2234                 # Disable progress bars when uploading models during checkpoints to avoid polluting stdout
#    2235                 hf_hub_utils.disable_progress_bars()
# -> 2236                 return inner_training_loop(
#    2237                     args=args,
#    2238                     resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2625                         self.state.epoch = epoch + (step + 1 + steps_skipped) / steps_in_epoch
#    2626                         self.control = self.callback_handler.on_step_end(args, self.state, self.control)
# -> 2627                         self._maybe_log_save_evaluate(
#    2628                             tr_loss,
#    2629                             grad_norm,
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time, learning_rate)
#    3094         metrics = None
#    3095         if self.control.should_evaluate:
# -> 3096             metrics = self._evaluate(trial, ignore_keys_for_eval)
#    3097             is_new_best_metric = self._determine_best_metric(metrics=metrics, trial=trial)
#    3098
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _evaluate(self, trial, ignore_keys_for_eval, skip_scheduler)
#    3043
#    3044     def _evaluate(self, trial, ignore_keys_for_eval, skip_scheduler=False):
# -> 3045         metrics = self.evaluate(ignore_keys=ignore_keys_for_eval)
#    3046         self._report_to_hp_search(trial, self.state.global_step, metrics)
#    3047
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer_seq2seq.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix, **gen_kwargs)
#     195         self.gather_function = self.accelerator.gather
#     196         self._gen_kwargs = gen_kwargs
# --> 197         return super().evaluate(eval_dataset, ignore_keys=ignore_keys, metric_key_prefix=metric_key_prefix)
#     198
#     199     def predict(
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    4152
#    4153         eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 4154         output = eval_loop(
#    4155             eval_dataloader,
#    4156             description="Evaluation",
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    4346
#    4347             # Prediction step
# -> 4348             losses, logits, labels = self.prediction_step(model, inputs, prediction_loss_only, ignore_keys=ignore_keys)
#    4349             main_input_name = getattr(self.model, "main_input_name", "input_ids")
#    4350             inputs_decode = (
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer_seq2seq.py in prediction_step(self, model, inputs, prediction_loss_only, ignore_keys, **gen_kwargs)
#     331
#     332         with summon_full_params_context:
# --> 333             generated_tokens = self.model.generate(**generation_inputs, **gen_kwargs)
#     334
#     335         # Temporary hack to ensure the generation config is not initialized for each iteration of the evaluation loop
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py in generate(self, input_features, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, return_timestamps, task, language, is_multilingual, prompt_ids, prompt_condition_type, condition_on_prev_tokens, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, num_segment_frames, attention_mask, time_precision, time_precision_features, return_token_timestamps, return_segments, return_dict_in_generate, force_unique_generate_call, **kwargs)
#     617
#     618         # pass self.config for backward compatibility
# --> 619         init_tokens = self._retrieve_init_tokens(
#     620             input_features,
#     621             batch_size=batch_size,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py in _retrieve_init_tokens(self, input_features, batch_size, generation_config, config, num_segment_frames, kwargs)
#    1465         lang_ids = None
#    1466         if language is not None:
# -> 1467             lang_ids = [language_to_id(l) for l in languages]
#    1468         elif hasattr(generation_config, "lang_to_id") and is_lang_id_undefined:
#    1469             # language is not defined or intentially set to `None` to trigger language detection
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py in <listcomp>(.0)
#    1465         lang_ids = None
#    1466         if language is not None:
# -> 1467             lang_ids = [language_to_id(l) for l in languages]
#    1468         elif hasattr(generation_config, "lang_to_id") and is_lang_id_undefined:
#    1469             # language is not defined or intentially set to `None` to trigger language detection
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py in language_to_id(language)
#    1387             else:
#    1388                 is_language_code = len(language) == 2
# -> 1389                 raise ValueError(
#    1390                     f"Unsupported language: {language}. Language should be one of:"
#    1391                     f" {list(TO_LANGUAGE_CODE.values()) if is_language_code else list(TO_LANGUAGE_CODE.keys())}."
#
# ValueError: Unsupported language: romainian. Language should be one of: ['english', 'chinese', 'german', 'spanish', 'russian', 'korean', 'french', 'japanese', 'portuguese', 'turkish', 'polish', 'catalan', 'dutch', 'arabic', 'swedish', 'italian', 'indonesian', 'hindi', 'finnish', 'vietnamese', 'hebrew', 'ukrainian', 'greek', 'malay', 'czech', 'romanian', 'danish', 'hungarian', 'tamil', 'norwegian', 'thai', 'urdu', 'croatian', 'bulgarian', 'lithuanian', 'latin', 'maori', 'malayalam', 'welsh', 'slovak', 'telugu', 'persian', 'latvian', 'bengali', 'serbian', 'azerbaijani', 'slovenian', 'kannada', 'estonian', 'macedonian', 'breton', 'basque', 'icelandic', 'armenian', 'nepali', 'mongolian', 'bosnian', 'kazakh', 'albanian', 'swahili', 'galician', 'marathi', 'punjabi', 'sinhala', 'khmer', 'shona', 'yoruba', 'somali', 'afrikaans', 'occitan', 'georgian', 'belarusian', 'tajik', 'sindhi', 'gujarati', 'amharic', 'yiddish', 'lao', 'uzbek', 'faroese', 'haitian creole', 'pashto', 'turkmen', 'nynorsk', 'maltese', 'sanskrit', 'luxembourgish', 'myanmar', 'tibetan', 'tagalog', 'malagasy', 'assamese', 'tatar', 'hawaiian', 'lingala', 'hausa', 'bashkir', 'javanese', 'sundanese', 'cantonese', 'burmese', 'valencian', 'flemish', 'haitian', 'letzeburgesch', 'pushto', 'panjabi', 'moldavian', 'moldovan', 'sinhalese', 'castilian', 'mandarin'].

# %% [markdown]
# Our best WER is 32.0% - not bad for 8h of training data! We can make our model more accessible on the Hub with appropriate tags and README information.
# You can change these values to match your dataset, language and model
# name accordingly:

# %%
kwargs = {
    "dataset_tags": "mozilla-foundation/common_voice_11_0",
    "dataset": "Common Voice 11.0",  # a 'pretty' name for the training dataset
    "dataset_args": "config: hi, split: test",
    "language": "hi",
    "model_name": "Whisper Small Hi - Sanchit Gandhi",  # a 'pretty' name for our model
    "finetuned_from": "openai/whisper-small",
    "tasks": "automatic-speech-recognition",
}

# %% [markdown]
# The training results can now be uploaded to the Hub. To do so, execute the `push_to_hub` command and save the preprocessor object we created:

# %%
trainer.push_to_hub(**kwargs)

# %% [markdown]
# ## Building a Demo

# %% [markdown]
# Now that we've fine-tuned our model we can build a demo to show
# off its ASR capabilities! We'll make use of 🤗 Transformers
# `pipeline`, which will take care of the entire ASR pipeline,
# right from pre-processing the audio inputs to decoding the
# model predictions.
#
# Running the example below will generate a Gradio demo where we
# can record speech through the microphone of our computer and input it to
# our fine-tuned Whisper model to transcribe the corresponding text:

# %%
from transformers import pipeline
import gradio as gr

pipe = pipeline(model="sanchit-gandhi/whisper-small-hi")  # change to "your-username/the-name-you-picked"

def transcribe(audio):
    text = pipe(audio)["text"]
    return text

iface = gr.Interface(
    fn=transcribe,
    inputs=gr.Audio(source="microphone", type="filepath"),
    outputs="text",
    title="Whisper Small Hindi",
    description="Realtime demo for Hindi speech recognition using a fine-tuned Whisper small model.",
)

iface.launch()

# %% [markdown]
# ## Closing Remarks

# %% [markdown]
# In this blog, we covered a step-by-step guide on fine-tuning Whisper for multilingual ASR
# using 🤗 Datasets, Transformers and the Hugging Face Hub. For more details on the Whisper model, the Common Voice dataset and the theory behind fine-tuning, refere to the accompanying [blog post](https://huggingface.co/blog/fine-tune-whisper). If you're interested in fine-tuning other
# Transformers models, both for English and multilingual ASR, be sure to check out the
# examples scripts at [examples/pytorch/speech-recognition](https://github.com/huggingface/transformers/tree/main/examples/pytorch/speech-recognition).
